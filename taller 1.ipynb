# %%
#variable para almacenar telefono
telefono=3107759097
#variable que almacena el nombre
nombre="Eduardo"
print (nombre)
print (telefono)
# Out:
# Eduardo
# 3107759097

# %%
nombre_per = input("digite su nombre: ")
print(nombre_per)
# Out:
# digite su nombre: carlos
# carlos

# %%
#tuve que dejarlo sin espacios
Identificación = 79850000
Nombres = "Eduardo"
Apellidos = "Muñoz Rada"
Dirección = "calle 9 A 1 B este 88"
# por ejemplo el telefono si me deja sin la misma ortografia
Teléfono = 3107759097
Edad = "46 años"
# no me dejaba si estaba en minusculas ¿?
EstadoCivil = "casado"
Númerodehijos = 2
Estaturaencentímetros = 1.66
#no me dejaba sin la tilde
fechadecontratación = "03/02/2023" 
Sueldobásico = 1412000
DíasLaborados = 32
print(Identificación,Nombres,Apellidos,Dirección,telefono,Edad,EstadoCivil,Númerodehijos,Estaturaencentímetros,fechadecontratación,Sueldobásico,DíasLaborados)
# Out:
# 79850000 Eduardo Muñoz Rada calle 9 A 1 B este 88 3107759097 46 años casado 2 1.66 03/02/2023 1412000 32

# %%
Identificación = "79850000"
print(Identificación)
# Out:
# 79850000
