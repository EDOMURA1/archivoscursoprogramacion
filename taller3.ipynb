# %% [markdown]
# Taller 2:
#
# Dando continuidad con la primera entrega del proyecto, en esta oportunidad el estudiante debe realizar las siguientes validaciones utilizando la sentencia condicional IF.
#
# Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.
#
# Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
#
# Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.
#
# Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.

# %%
#datos basicos
edad = float(input("digite la edad del empleado en años: "))
casadoyconhijos = input("digite si o no es casado y tiene hijos: ")
sueldo = float(input("digite el sueldo basico: $ "))
diastrabajados = int(input("digite los dias trabajados: "))

#Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.
if edad > 55:
  bono = sueldo * 0.05
  print("tiene derecho a bono prepension del 5%: ${:,.0f}".format(bono)) 
else:
  print("no tiene derecho a bono")

#Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
if casadoyconhijos == "si":
  print("Si se le otorga paseo en diciembre")
else:
  print("No se le otorga paseo en diciembre")

#Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo; 
#Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.
if sueldo >= 1000000 and sueldo <=1500000:
  comi1 = sueldo * 0.02
  totalcomi1 = comi1 + sueldo
  print("gana comision del 2%: $ {:,.0f}".format(comi1))
elif sueldo >= 1500001 and sueldo <=2000000:
  comi2 = sueldo * 0.05
  totalcomi2 = comi2 + sueldo
  print("gana comision del 5%: $ {:,.0f}".format(comi2))
else:
  print("No tiene comision")

#Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.
if diastrabajados > 20 and sueldo < 1000000:
    print("tiene derecho a bono de alimentacion") 
else:
  print("no tiene derecho a bono de alimentacion")
# Out:
# digite la edad del empleado en años: 56
# digite si o no es casado y tiene hijos: si
# digite el sueldo basico: $ 2000000
# digite los dias trabajados: 21
# tiene derecho a bono prepension del 5%: $100,000
# Si se le otorga paseo en diciembre
# gana comision del 5%: $ 100,000
# no tiene derecho a bono de alimentacion
